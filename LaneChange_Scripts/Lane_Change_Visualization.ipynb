# %% [markdown]
# # Data visualizations

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ## Constants

# %%
LANGECHANGE_AND_BREAKING_DATA_PATH = "data/braking_and_lanechange.csv"
BRAKING_CUT = "data/braking_cut.csv"
EIGHT_BRAKING_CUTS = "data/braking_cut_8_brakes.csv"
BRAKING_ONE_ROUND = "data/braking_eine_Runde.csv"
LC_ONE_ROUND = "data/LC_one_round.csv"

# %% [markdown]
# ## Initialize data frame

# %%
LCandBrakingDF = pd.read_csv(LANGECHANGE_AND_BREAKING_DATA_PATH, sep=";", index_col=False)
brakingCut = pd.read_csv(BRAKING_CUT, sep=";", index_col=False)
eightBrakingCuts = pd.read_csv(EIGHT_BRAKING_CUTS, sep=";", index_col=False)
brakingOneRound = pd.read_csv(BRAKING_ONE_ROUND, sep=";", index_col=False)
lcOneRound = pd.read_csv(LC_ONE_ROUND, sep=";", index_col=False)

dataframes = [LCandBrakingDF, brakingCut, eightBrakingCuts, brakingOneRound, lcOneRound] # put into an array for simplifying data processing

# %%
LCandBrakingDF
# Out:
#        sampleTimeStamp.seconds  sampleTimeStamp.microseconds        lat  \
# 0                   1646666459                         92289  57.719199
# 1                   1646666459                        142313  57.719199
# 2                   1646666459                        192324  57.719199
# 3                   1646666459                        242353  57.719199
# 4                   1646666459                        292302  57.719199
# ...                        ...                           ...        ...
# 10876               1646667002                        910589  57.719113
# 10877               1646667002                        960554  57.719113
# 10878               1646667003                         10583  57.719113
# 10879               1646667003                         60578  57.719113
# 10880               1646667003                        110577  57.719113
#
#              lon     speed  accel_lon  accel_trans  accel_down
# ...

# %%
brakingCut
# Out:
#      sampleTimeStamp.seconds  sampleTimeStamp.microseconds        lat  \
# 0                 1646666550                         45396  57.718742
# 1                 1646666550                         95404  57.718743
# 2                 1646666550                        145481  57.718744
# 3                 1646666550                        195461  57.718744
# 4                 1646666550                        245397  57.718745
# ..                       ...                           ...        ...
# 395               1646666569                        796071  57.718956
# 396               1646666569                        846028  57.718956
# 397               1646666569                        896059  57.718956
# 398               1646666569                        946060  57.718957
# 399               1646666569                        996092  57.718957
#
#            lon     speed  accel_lon  accel_trans  accel_down
# 0    11.958157  3.919986   0.958510     1.773054   -0.070448
# ...

# %%
eightBrakingCuts
# Out:
#       sampleTimeStamp.seconds  sampleTimeStamp.microseconds        lat  \
# 0                  1646666550                         45396  57.718742
# 1                  1646666550                         95404  57.718743
# 2                  1646666550                        145481  57.718744
# 3                  1646666550                        195461  57.718744
# 4                  1646666550                        245397  57.718745
# ...                       ...                           ...        ...
# 4394               1646666769                        752738  57.718744
# 4395               1646666769                        802735  57.718742
# 4396               1646666769                        852804  57.718741
# 4397               1646666769                        902834  57.718740
# 4398               1646666769                        952825  57.718739
#
#             lon     speed  accel_lon  accel_trans  accel_down
# ...

# %%
brakingOneRound
# Out:
#      sampleTimeStamp.seconds  sampleTimeStamp.microseconds        lat  \
# 0                 1646666720                          1146  57.718783
# 1                 1646666720                         51097  57.718782
# 2                 1646666720                        101091  57.718782
# 3                 1646666720                        151115  57.718782
# 4                 1646666720                        201104  57.718782
# ..                       ...                           ...        ...
# 995               1646666769                        752738  57.718744
# 996               1646666769                        802735  57.718742
# 997               1646666769                        852804  57.718741
# 998               1646666769                        902834  57.718740
# 999               1646666769                        952825  57.718739
#
#            lon     speed  accel_lon  accel_trans  accel_down
# 0    11.958487  1.832739  -0.024754     0.187137    0.156737
# ...

# %%
lcOneRound
# Out:
#       sampleTimeStamp.seconds  sampleTimeStamp.microseconds        lat  \
# 0                  1663765141                        811423  57.718584
# 1                  1663765141                        861423  57.718584
# 2                  1663765141                        911406  57.718584
# 3                  1663765141                        961382  57.718583
# 4                  1663765142                         11418  57.718583
# ...                       ...                           ...        ...
# 1070               1663765195                        311918  57.718596
# 1071               1663765195                        362012  57.718596
# 1072               1663765195                        411908  57.718596
# 1073               1663765195                        461957  57.718596
# 1074               1663765195                        511870  57.718596
#
#             lon     speed  accel_lon  accel_trans  accel_down
# ...

# %%
for df in dataframes:
    df['ts'] = (df['sampleTimeStamp.seconds']*1000000)+df['sampleTimeStamp.microseconds']
    df.drop(columns=['sampleTimeStamp.seconds', 'sampleTimeStamp.microseconds'], inplace=True)

LCandBrakingDF.to_csv("brakeAndLaneChangesWithTimestamp.csv", index=False, sep=";")
eightBrakingCuts.to_csv("eightBrakesWithTimestamp.csv", index=False, sep=";")
lcOneRound.to_csv("LCOneRoundWithTimestamp.csv", index=False, sep=";")
#LCandBreakingDF['ts'] = (LCandBreakingDF['sampleTimeStamp.seconds']*1000000)+LCandBreakingDF['sampleTimeStamp.microseconds']
#LCandBreakingDF = LCandBreakingDF.drop(columns=['sampleTimeStamp.seconds', 'sampleTimeStamp.microseconds'])

# %%
LCandBrakingDF
# Out:
#              lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0      57.719199  11.956858  0.004495  -0.007067     0.010191    0.023798
# 1      57.719199  11.956858  0.001079   0.016714    -0.053451   -0.091782
# 2      57.719199  11.956858  0.001933  -0.064363     0.020932    0.089398
# 3      57.719199  11.956858  0.004307   0.086184    -0.057222   -0.138364
# 4      57.719199  11.956858  0.002647  -0.086896     0.039136    0.156289
# ...          ...        ...       ...        ...          ...         ...
# 10876  57.719113  11.956551  0.103031  -0.044285     0.045432    0.053489
# 10877  57.719113  11.956551  0.102807   0.014795    -0.037504   -0.057202
# 10878  57.719113  11.956551  0.104186  -0.078249    -0.005558    0.024890
# 10879  57.719113  11.956552  0.104180   0.027714    -0.033445   -0.075416
# 10880  57.719113  11.956552  0.104977  -0.078318    -0.023231    0.039319
#
#                      ts
# 0      1646666459092289
# 1      1646666459142313
# ...

# %%
brakingCut
# Out:
#            lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0    57.718742  11.958157  3.919986   0.958510     1.773054   -0.070448
# 1    57.718743  11.958154  3.880830   1.153120     1.779929   -0.113446
# 2    57.718744  11.958151  3.842020   1.154697     1.804190   -0.091907
# 3    57.718744  11.958148  3.802006   1.139854     1.707745    0.049844
# 4    57.718745  11.958145  3.761051   1.152900     1.682915    0.044875
# ..         ...        ...       ...        ...          ...         ...
# 395  57.718956  11.956947  2.119671  -1.376511     0.001714    0.101588
# 396  57.718956  11.956946  2.189391  -1.494308     0.000360    0.052744
# 397  57.718956  11.956944  2.262589  -1.475314    -0.008052   -0.013644
# 398  57.718957  11.956942  2.338461  -1.597440     0.011448    0.109799
# 399  57.718957  11.956940  2.413346  -1.414659     0.054481    0.073955
#
#                    ts
# 0    1646666550045396
# 1    1646666550095404
# 2    1646666550145481
# ...

# %% [markdown]
# ## Extracting 8 breaks from main data

# %%
eightBrakingCuts
# Out:
#             lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57.718742  11.958157  3.919986   0.958510     1.773054   -0.070448
# 1     57.718743  11.958154  3.880830   1.153120     1.779929   -0.113446
# 2     57.718744  11.958151  3.842020   1.154697     1.804190   -0.091907
# 3     57.718744  11.958148  3.802006   1.139854     1.707745    0.049844
# 4     57.718745  11.958145  3.761051   1.152900     1.682915    0.044875
# ...         ...        ...       ...        ...          ...         ...
# 4394  57.718744  11.958597  2.942660  -0.109660    -1.716671    0.125163
# 4395  57.718742  11.958598  2.974508  -0.200638    -1.606261   -0.168215
# 4396  57.718741  11.958598  3.004279  -0.054665    -1.799528    0.009359
# 4397  57.718740  11.958599  3.032090  -0.036978    -1.956327    0.030983
# 4398  57.718739  11.958599  3.058596  -0.136479    -1.980069   -0.095787
#
#                     ts
# 0     1646666550045396
# 1     1646666550095404
# ...

# %%
LCandBrakingDF
# Out:
#              lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0      57.719199  11.956858  0.004495  -0.007067     0.010191    0.023798
# 1      57.719199  11.956858  0.001079   0.016714    -0.053451   -0.091782
# 2      57.719199  11.956858  0.001933  -0.064363     0.020932    0.089398
# 3      57.719199  11.956858  0.004307   0.086184    -0.057222   -0.138364
# 4      57.719199  11.956858  0.002647  -0.086896     0.039136    0.156289
# ...          ...        ...       ...        ...          ...         ...
# 10876  57.719113  11.956551  0.103031  -0.044285     0.045432    0.053489
# 10877  57.719113  11.956551  0.102807   0.014795    -0.037504   -0.057202
# 10878  57.719113  11.956551  0.104186  -0.078249    -0.005558    0.024890
# 10879  57.719113  11.956552  0.104180   0.027714    -0.033445   -0.075416
# 10880  57.719113  11.956552  0.104977  -0.078318    -0.023231    0.039319
#
#                      ts
# 0      1646666459092289
# 1      1646666459142313
# ...

# %% [markdown]
# ### verify 8 brakes is a subset of lanechange and brakes

# %%
sortedEightBrakingCuts = eightBrakingCuts.sort_values(by=list(eightBrakingCuts.columns)).reset_index(drop=True)
sortedLCandBrakingDF = LCandBrakingDF.sort_values(by=list(LCandBrakingDF.columns)).reset_index(drop=True)

set1 = set(map(tuple, sortedEightBrakingCuts.to_numpy()))
set2 = set(map(tuple, sortedLCandBrakingDF.to_numpy()))
print(set1.issubset(set2))
# Out:
# True

# %%
### Remove the 8 brakes csv from the lane change & brakes csv

# %%
#merged_df = LCandBrakingDF.merge(eightBrakingCuts, indicator=True, how='inner')
#matched_rows = merged_df[merged_df['_merge'] == 'both']
    
#"brakeAndLaneChangesWithTimestamp.csv", index=False)
#eightBrakingCuts.to_csv("eightBrakesWithTimestamp.csv"
                        
with open("brakeAndLaneChangesWithTimestamp.csv", newline='') as all_set:
    reader = csv.DictReader(all_set, delimiter=';')
    data_all = list(reader)

with open("eightBrakesWithTimestamp.csv", newline='') as subset:
    reader = csv.reader(subset, delimiter=';')
    dataEightBrakes = set([';'.join(row) for row in reader])

lcData = []
for row in data_all:
    if ';'.join(row.values()) not in dataEightBrakes:
        lcData.append(row)

with open('lc_data.csv', 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=lcData[0].keys(), delimiter=";")
    writer.writeheader()
    writer.writerows(lcData)


lcDF = pd.read_csv('lc_data.csv', sep=";")
#lcDF = LCandBrakingDF.drop(matched_rows.index).reset_index(drop=True)
lcDF
#lcDF.to_csv("data/lane_changes.csv", index=False)
# Out:
#             lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57.719199  11.956858  0.004495  -0.007067     0.010191    0.023798
# 1     57.719199  11.956858  0.001079   0.016714    -0.053451   -0.091782
# 2     57.719199  11.956858  0.001933  -0.064363     0.020932    0.089398
# 3     57.719199  11.956858  0.004307   0.086184    -0.057222   -0.138364
# 4     57.719199  11.956858  0.002647  -0.086896     0.039136    0.156289
# ...         ...        ...       ...        ...          ...         ...
# 6477  57.719113  11.956551  0.103031  -0.044285     0.045432    0.053489
# 6478  57.719113  11.956551  0.102807   0.014795    -0.037504   -0.057202
# 6479  57.719113  11.956551  0.104186  -0.078249    -0.005558    0.024890
# 6480  57.719113  11.956552  0.104180   0.027714    -0.033445   -0.075416
# 6481  57.719113  11.956552  0.104977  -0.078318    -0.023231    0.039319
#
#                     ts
# 0     1646666459092289
# 1     1646666459142313
# ...

# %%
# confirming if brake data is in lcdf
sortedEightBrakingCuts = eightBrakingCuts.sort_values(by=list(eightBrakingCuts.columns)).reset_index(drop=True)
sortedlcDF = lcDF.sort_values(by=list(lcDF.columns)).reset_index(drop=True)

set1 = set(map(tuple, sortedEightBrakingCuts.to_numpy()))
set2 = set(map(tuple, sortedlcDF.to_numpy()))
print(set1.issubset(set2))
# Out:
# False

# %%
lcDF
# Out:
#             lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57.719199  11.956858  0.004495  -0.007067     0.010191    0.023798
# 1     57.719199  11.956858  0.001079   0.016714    -0.053451   -0.091782
# 2     57.719199  11.956858  0.001933  -0.064363     0.020932    0.089398
# 3     57.719199  11.956858  0.004307   0.086184    -0.057222   -0.138364
# 4     57.719199  11.956858  0.002647  -0.086896     0.039136    0.156289
# ...         ...        ...       ...        ...          ...         ...
# 6477  57.719113  11.956551  0.103031  -0.044285     0.045432    0.053489
# 6478  57.719113  11.956551  0.102807   0.014795    -0.037504   -0.057202
# 6479  57.719113  11.956551  0.104186  -0.078249    -0.005558    0.024890
# 6480  57.719113  11.956552  0.104180   0.027714    -0.033445   -0.075416
# 6481  57.719113  11.956552  0.104977  -0.078318    -0.023231    0.039319
#
#                     ts
# 0     1646666459092289
# 1     1646666459142313
# ...

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Long Lat visualization

# %%
#faktor_multiply = 1000000; offset = 10

#LCandBrakingDF['lon'] = LCandBrakingDF.apply(lambda x: int(x['lon']*faktor_multiply) , axis=1)
#LCandBrakingDF['lat'] = LCandBrakingDF.apply(lambda x: int(x['lat']*faktor_multiply) , axis=1)


LCandBrakingDF.plot(x = 'lon', y = 'lat')
# Out:
# <Axes: xlabel='lon'>

# %% [markdown]
# ## Single round lane change dataset analysis!

# %% [markdown]
# Looking at LC_one_round.csv here to have a direct example on what a lane change looks like.
#
# From this, we will analyze the dataset containing all lane change maneuvers via analyzing the long lat, and accel_lon and accel_trans corresponding time stamps

# %%
lcOneRound
# Out:
#             lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57.718584  11.958627  0.194917   1.242619     0.014429   -0.059848
# 1     57.718584  11.958627  0.163694   1.228876     0.063122    0.026755
# 2     57.718584  11.958627  0.163126   1.335767     0.117609   -0.135379
# 3     57.718583  11.958627  0.180266   1.359777     0.060994   -0.048702
# 4     57.718583  11.958627  0.222574   1.487516     0.034467   -0.162102
# ...         ...        ...       ...        ...          ...         ...
# 1070  57.718596  11.958487  0.152977  -0.009616     0.032255    0.003031
# 1071  57.718596  11.958487  0.150944  -0.025932     0.018902   -0.010924
# 1072  57.718596  11.958487  0.150021  -0.035663     0.026482    0.024062
# 1073  57.718596  11.958487  0.148947  -0.008712     0.021690   -0.004186
# 1074  57.718596  11.958487  0.145816  -0.037292    -0.009685    0.030689
#
#                     ts
# 0     1663765141811423
# 1     1663765141861423
# ...

# %%
print(lcOneRound["ts"].max() - lcOneRound["ts"].min())
lcOneRound.plot(x="lon", y="lat")
# Out:
# 53700447
# <Axes: xlabel='lon'>

# %%
lcOneRound.plot(x="ts", y=["accel_lon", "accel_trans"])
# Out:
# <Axes: xlabel='ts'>

# %%
lcOneRoundAccelTransLargerThanFour = lcOneRound[lcOneRound['accel_trans'] > 4]
lcOneRoundAccelTransLargerThanFour
#lcOneRoundDFF = lcOneRoundDFF[(lcOneRoundDFFF['ts'] > 1646666459092289) & (lcOneRoundDFF['ts'] < 1646666795453955)]
# Out:
#            lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 708  57.718879  11.957637  11.92711  -0.111060     4.492947    1.586623
# 709  57.718877  11.957646  11.91079   0.446288     4.338321    0.021631
# 710  57.718874  11.957655  11.90519   0.322005     4.249693    0.628299
# 712  57.718870  11.957674  11.89840  -0.299831     4.252394    0.588553
# 713  57.718868  11.957683  11.89191   0.884583     4.954717   -0.055070
# 714  57.718866  11.957693  11.89861  -0.234422     5.182184    1.082526
# 715  57.718864  11.957702  11.89953  -0.008587     4.179891    0.274768
#
#                    ts
# 708  1663765177211777
# 709  1663765177261792
# 710  1663765177311768
# 712  1663765177411772
# 713  1663765177461774
# 714  1663765177511782
# 715  1663765177561839

# %%
lcOneRound[(lcOneRound['ts'] > 1663765174211777) & (lcOneRound['ts'] < 1663765177561839)].plot(x="ts", y=["accel_lon", "accel_trans"])
# Out:
# <Axes: xlabel='ts'>

# %%
lcOneRound[(lcOneRound['ts'] > 1663765174211777) & (lcOneRound['ts'] < 1663765177561839)].plot(x="lon", y="lat")
# Out:
# <Axes: xlabel='lon'>

# %%
lcOneRound[(lcOneRound['ts'] > 1663765174211777) & (lcOneRound['ts'] < 1663765189561839)].plot(x="ts", y=["accel_lon", "accel_trans"])
# Out:
# <Axes: xlabel='ts'>

# %%
lcOneRound[(lcOneRound['ts'] > 1663765174211777) & (lcOneRound['ts'] < 1663765189561839)].plot(x="lon", y="lat")
# Out:
# <Axes: xlabel='lon'>

# %%
lcDF.plot(x="lon",y="lat")
# Out:
# <Axes: xlabel='lon'>

# %% [markdown]
# ### Acceleration visualizations

# %%
LCandBrakingDF.plot(x="ts", y=["accel_lon", "accel_trans", "accel_down"])
# Out:
# <Axes: xlabel='ts'>

# %%
lcDF.plot(x="ts", y=["accel_lon", "accel_trans", "accel_down"])
# Out:
# <Axes: xlabel='ts'>

# %%
print(lcDF['ts'].min())
# Out:
# 1646666459092289

# %%
print(lcDF['ts'].max())
# Out:
# 1646667003110577

# %%
lcDFF = lcDF[(lcDF['ts'] > 1646666459092289) & (lcDF['ts'] < 1646666795453955)]

# %%
lcDFF.plot(x="ts", y=["accel_lon"])
# Out:
#   Cell In[264], line 1
#     lcDFF.plot(x="ts", y=["accel_lon])
#                                       ^
# SyntaxError: EOL while scanning string literal

# %%
lcDFF.plot(x="ts", y=["speed"])
# Out:
# <Axes: xlabel='ts'>

# %%
lcDFF.plot(x="lon", y="lat")
# Out:
# <Axes: xlabel='lon'>

# %%
eightBrakingDFF = eightBrakingCuts[(eightBrakingCuts['ts'] > 1646666679049799) & (eightBrakingCuts['ts'] < 1646666733049799)]
eightBrakingDFF.plot(x="lon", y="lat")
# Out:
# <Axes: xlabel='lon'>

# %%
eightBrakingDFF.plot(x="ts", y=["accel_lon", "accel_trans", "accel_down"])
eightBrakingCuts
# Out:
#             lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57.718742  11.958157  3.919986   0.958510     1.773054   -0.070448
# 1     57.718743  11.958154  3.880830   1.153120     1.779929   -0.113446
# 2     57.718744  11.958151  3.842020   1.154697     1.804190   -0.091907
# 3     57.718744  11.958148  3.802006   1.139854     1.707745    0.049844
# 4     57.718745  11.958145  3.761051   1.152900     1.682915    0.044875
# ...         ...        ...       ...        ...          ...         ...
# 4394  57.718744  11.958597  2.942660  -0.109660    -1.716671    0.125163
# 4395  57.718742  11.958598  2.974508  -0.200638    -1.606261   -0.168215
# 4396  57.718741  11.958598  3.004279  -0.054665    -1.799528    0.009359
# 4397  57.718740  11.958599  3.032090  -0.036978    -1.956327    0.030983
# 4398  57.718739  11.958599  3.058596  -0.136479    -1.980069   -0.095787
#
#                     ts
# 0     1646666550045396
# 1     1646666550095404
# ...

# %%
lcDF
# Out:
#             lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57.719199  11.956858  0.004495  -0.007067     0.010191    0.023798
# 1     57.719199  11.956858  0.001079   0.016714    -0.053451   -0.091782
# 2     57.719199  11.956858  0.001933  -0.064363     0.020932    0.089398
# 3     57.719199  11.956858  0.004307   0.086184    -0.057222   -0.138364
# 4     57.719199  11.956858  0.002647  -0.086896     0.039136    0.156289
# ...         ...        ...       ...        ...          ...         ...
# 6477  57.719113  11.956551  0.103031  -0.044285     0.045432    0.053489
# 6478  57.719113  11.956551  0.102807   0.014795    -0.037504   -0.057202
# 6479  57.719113  11.956551  0.104186  -0.078249    -0.005558    0.024890
# 6480  57.719113  11.956552  0.104180   0.027714    -0.033445   -0.075416
# 6481  57.719113  11.956552  0.104977  -0.078318    -0.023231    0.039319
#
#                     ts
# 0     1646666459092289
# 1     1646666459142313
# ...

# %%
eightBrakingDFF = eightBrakingCuts[(eightBrakingCuts['ts'] > 1646666679049799) & (eightBrakingCuts['ts'] < 1646666733049799)]
LCandBrakingDFF = LCandBrakingDF

# %% [markdown]
# # Results

# %% [markdown]
# - one round roughly takes 54000000 microseconds.
# - there are 324060778 microseconds between the last and first timestamp.
#     - Hence, there are rouhgly 6 rounds made in total, with potentially more than one lane change       occuring in them.
